2025
	Approved
Sapinski Mariusz Gracjan
	
		
	
	
Paternity Leave
	
14.02.2025
	Approved
Sapinski Mariusz Gracjan
	
8.3 Hours
	
	
	
Home Office
	
13.02.2025
	Approved
Sapinski Mariusz Gracjan
	
		
	
	
Paternity Leave
	
07.02.2025
	Approved
Sapinski Mariusz Gracjan
	
8.3 Hours
	
	
	
Home Office
	
06.02.2025
	Approved
Sapinski Mariusz Gracjan
	
		
	
	
Paternity Leave
	
31.01.2025
	Approved
Sapinski Mariusz Gracjan
	
8.3 Hours
	
	
	
Home Office
	
30.01.2025
	Approved
Sapinski Mariusz Gracjan
	
		
	
	
Paternity Leave
	
24.01.2025
	Approved
Sapinski Mariusz Gracjan
	
8.3 Hours
	
	
	
Home Office
	
23.01.2025
	Approved
Sapinski Mariusz Gracjan
	
		
	
	
Home Office
	
23.01.2025
	Approved
Sapinski Mariusz Gracjan
	
		
	
	
Paternity Leave
	
16.01.2025 – 17.01.2025
	Approved
Sapinski Mariusz Gracjan
	
16.6 Hours
	
	
	
Paternity Leave
	
15.01.2025
	Approved
	
4.15 Hours
	
	
	
Home Office
	
09.01.2025
	Approved
Sapinski Mariusz Gracjan
	
		
	
	
Home Office
	
09.01.2025
	Approved
Sapinski Mariusz Gracjan
	
		
	

"""

# %%
allowance_data = """

Leave Type
	
Validity
	
Available
	
Planned
	
Used
	
Entitlement
		
	
Holiday
	
01.08.2024 – 31.12.2025
	
0 Hours
0 Hours
	
41.5 Hours
	
41.5 Hours
		
	
Holiday
	
01.01.2025 – 31.12.2026
	
8.3 Hours
107.9 Hours
	
91.3 Hours
	
207.5 Hours
		
	
	
16.12.2024 – 15.12.2025
	
4.15 Hours
0 Hours
	
78.85 Hours
	
83 Hours
"""

# %%
import pandas as pd 
import numpy as np
#remove all the blan lines 
def Formatdata(data, rowlen= 5):

    data =  data.strip()   
    cleanD = []
    line=''
    for s in data:  
        
        if(s=='\n'):
            cleanD.append(line)
            line = ''
        else:
            line+=s
    cleanD.append(line)
    data = []
    for d in cleanD: 
        if(len(d)>0):
            # remove Hours 
            d = d.replace("Hours", "").strip()
            data.append(d)

    headder =  data[0:rowlen]
    data = data[rowlen+1:len(data)]
    
    #print(data) 
    #df = pd.DataFrame(data)
    return headder, data


def conglam(vec, bin_size =6 ): 
    vec = np.array(vec)
    N = len(vec)
    remainder = N % bin_size
    if remainder != 0:
        pad_size = bin_size - remainder
        vec = np.pad(vec, (0, pad_size), constant_values=np.nan)

    # reshape into bins
    reshaped = vec.reshape(-1, bin_size)
    for row in reshaped: 
        
    return reshaped


headder, alowance = Formatdata(allowance_data) 
headder,allocated =  Formatdata(Indata) 

print(alowance) 
alowance = conglam(alowance)

print(alowance)
# Out:
# ['Holiday', '01.08.2024 – 31.12.2025', '0', '0', '41.5', '41.5', 'Holiday', '01.01.2025 – 31.12.2026', '8.3', '107.9', '91.3', '207.5', '16.12.2024 – 15.12.2025', '4.15', '0', '78.85', '83']
# [['Holiday' '01.08.2024 – 31.12.2025' '0' '0' '41.5' '41.5']
#  ['Holiday' '01.01.2025 – 31.12.2026' '8.3' '107.9' '91.3' '207.5']
#  ['16.12.2024 – 15.12.2025' '4.15' '0' '78.85' '83' 'nan']]
