# %% [markdown]
# # Covert Transport to human
# The PSI TRANSPORT code is a punch card style interface and very hard to look at, here is a code to take a input file and covert it into a human readable interface. Later versions are planed to convert the inptu into other languages too

# %%
import os 
#input file 
inputDir =  "/mnt/c/Users/stu_w/OneDrive/Software/TRANSPORT/scripts"
filename =  "Beamline220MeV.dat"

FnDir =os.path.join(inputDir, filename)
#open file and copy to memory 
print("opening: ", FnDir)
with open(FnDir,'r') as file:
    lines = file.readlines()
    lines = [line.rstrip() for line in lines]
print("File has ", len(lines), " lines in mem")
# Out:
# opening:  /mnt/c/Users/stu_w/OneDrive/Software/TRANSPORT/scripts/Beamline220MeV.dat
# File has  189  lines in mem

# %% [markdown]
# # parsing the file to readable units
# From the manual http://stefano.sinigardi.it/published/Manuale_Transport.pdf the inputs will be rewritten and comments removed

# %%
# is a number function 
def isAnumber(string = ''):
    
    if(string.find('-')>=0):
        string=string[string.find('-')+1:len(string)]
        #print(string)
    return string.replace('.','',1).isdigit()
#test 
#print(isAnumber("22.34sdfdsdf"))

# %%
import numpy as np


def LookUpEl(El=0, com = ''):
    #elemet number 
    var=[]
    #has lable 
    c = com.split(' ')
    num = np.floor(float(c[0]))
    if(len(c)>1):        
        c = c[1:len(c)]
    else: 
        num = 0    
    # remove empty results
    c = [ele for ele in c if ele.strip()]
    #print(c)

    #process     
    if(int(num) == 0 ):# command for program 
        return {'EntryNo':El,'Element':'ProgramC', 'command': c[0]}
    #Beam init 
    if(int(num) == 1 ):
        dic = {'EntryNo':El,'Element':'Beam'}
        v = [ 'x[cm]', 'Px[mr]','y','Py','Blen[cm]','disp[%]','Pmom','','']
        for i, val in enumerate(c):
            if(isAnumber(val)):            
                dic[v[i]]=float(val)
            else:
                dic['name'] = val[val.find('/')+1:-1]
        return dic
    
    if(num == 2 ):
        dic = {'EntryNo':El,'Element':'Rotation'}
        v = [ 'angle[deg]', '','']
        for i, val in enumerate(c):
            if(isAnumber(val)):            
                dic[v[i]]=float(val)
            else:
                dic['name'] = val[val.find('/')+1:-1]
        return dic        
    if(num == 3 ):
        dic = {'EntryNo':El,'Element':'Drift'}
        v = [ 'Len[m]', '','']
        for i, val in enumerate(c):
            if(isAnumber(val)):            
                dic[v[i]]=float(val)
            else:
                dic['name'] = val[val.find('/')+1:-1]
        return dic
        
    if(num == 4):
        dic = {'EntryNo':El,'Element':'BendingMag'}
        v = [ 'Len[m]', 'angle[deg]','FeildGrad[n]','','']
        #print (c)
        for i, val in enumerate(c):
            if(isAnumber(val)):            
                dic[v[i]]=float(val)
            else:
                dic['name'] = val[val.find('/')+1:-1]
        try: 
            th = dic['angle[deg]']
            l = dic['Len[m]']
            dic['BendRad'] = l/((th/180.)*np.pi)
        except:
            dic['BendRad'] =0            
        return dic
    if(num == 5):
        dic = {'EntryNo':El,'Element':'QP'}
        v = [ 'Len[m]', 'Feild[kG]','HalfApature','','']
        for i, val in enumerate(c):
            if(isAnumber(val)):            
                dic[v[i]]=float(val)
            else:
                dic['name'] = val[val.find('/')+1:-1]
        return dic        
    if(num == 6):
        dic = {'EntryNo':El,'Element':'Transform'}
        v = [ 'Len[m]', 'Feild[kG]','FeildGrad','']
        for i, val in enumerate(c):
            if(isAnumber(val)):            
                dic[v[i]]=float(val)
            else:
                dic['name'] = val[val.find('/')+1:-1]
        return dic
        
    if(num == 7):
        dic = {'EntryNo':El,'Element':'BeamCentShift'}
        v = [ 'x[cm]', 'Px[mrad]','y[cm]', 'Py[mrad]','len[cm]','disp[%]','']
        for i, val in enumerate(c):
            if(isAnumber(val)):            
                dic[v[i]]=float(val)
            else:
                dic['name'] = val[val.find('/')+1:-1]
        return dic
        
    if(num == 8):
        dic = {'EntryNo':El,'Element':'AlignTollerance'}
        v = [ 'x[cm]', 'Px[mrad]','y[cm]', 'Py[mrad]','z[cm]','rot[mrad]','']
        for i, val in enumerate(c):
            if(isAnumber(val)):            
                dic[v[i]]=float(val)
            else:
                dic['name'] = val[val.find('/')+1:-1]
        return dic
       
    if(num == 9):
        dic = {'EntryNo':El,'Element':'RepeatContrl'}
        v = [ 'Nrepeat','']
        for i, val in enumerate(c):
            if(isAnumber(val)):            
                dic[v[i]]=float(val)
            else:
                dic['name'] = val[val.find('/')+1:-1]
        return dic
        
    if(num == 10 or num == -10):
        dic = {'EntryNo':El,'Element':'FitConstr'}
        v = [ 'function', 'J','desiredVal]','accurcy','']
        for i, val in enumerate(c):
            if(isAnumber(val)):            
                dic[v[i]]=float(val)
            else:
                dic['name'] = val[val.find('/')+1:-1]
        return dic
        
    if(num == 11):
        dic = {'EntryNo':El,'Element':'Accelerator'}
        v = [ 'Len[m]', 'EnergyGain[GeV]','PhaseLag[deg]','WaveLength','']
        for i, val in enumerate(c):
            if(isAnumber(val)):            
                dic[v[i]]=float(val)
            else:
                dic['name'] = val[val.find('/')+1:-1]
        return dic
        return 'Accelerator'
    if(num == 12):
        dic = {'EntryNo':El,'Element':'BeamRotElipse'}
        v = [ 'R12','R13','R14','R15','R16','R23','R24','R25','R26','R34','R35','R36', 'R45','R46','R56','','' ]
        for i, val in enumerate(c):
            if(isAnumber(val)):            
                dic[v[i]]=float(val)
            else:
                dic['name'] = val[val.find('/')+1:-1]
        return dic
        
    if(num == 13 ):
        dic = {'EntryNo':El,'Element':'In/OutOpts'}
        v = [ 'ControlNum','']
        for i, val in enumerate(c):
            if(isAnumber(val)):            
                dic[v[i]]=float(val)
            else:
                dic['name'] = val[val.find('/')+1:-1]
        return dic
       
    if(num == 14):
        dic = {'EntryNo':El,'Element':'RMatrix'}
        v = [ 'Rji', 'Rj2','Rj3','Rj4','Rj5','Rj6','j','']
        #print(c)
        for i, val in enumerate(c):
            #print(i, " : ", val, " : ", v[i])
            if(isAnumber(val)):            
                dic[v[i]]=float(val)
            else:
                dic['name'] = val[val.find('/')+1:-1]
        return dic
        
    if(num == 15):
        dic = {'EntryNo':El,'Element':'Units'}
        v = [ 'code', 'Unit','ScaleFctr','']
        unit = ['','XY[cm]','PxPy[mr]','Y[cm]','Py[mr]','BunchLen[cm]','dP[%]','angle[deg]','Len[m]','Bfield[kG]','Mass[Me]','Pgain[GeV/c]', '']
        print(c)
        try: 
            opt  = int(float(c[0]))
            name = c[1]            
            val  = float(c[2])
            dic['oldUnit']  = unit[opt]
            dic['code']     = opt
            dic['newUnit']  = name[name.find('/')+1:-1]
            dic['ScaleFctr']= val
            
        except:
            dic["error"]  = 1           
        return dic
    
    if(num == 16):
        dic = {'EntryNo':El,'Element':'BendingMagPar'}
        v = [ 'QuadTermBend','P[cm]','M/m' ,'W/2[cm]',
             'g/2[cm]','Len[cm]','k1-fringe','k2-fringe',
             'Crv_ben_en_Face','Crv_ben_ex_Face',
             'FocPlaneRot','','','']
        try: 
            opt = int(float(c[0]))
            val = float(c[1])
            name= c[2]
            dic[v[opt]]= val
            dic['name'] = name[name.find('/')+1:-1]
        except:
            dic["error"] = 1           
        return dic
    
    if(num == 17):
        dic = {'EntryNo':El,'Element':'BendingMag'}
        v = [ '', '','','']
        for i, val in enumerate(c):
            if(isAnumber(val)):            
                dic[v[i]]=float(val)
            else:
                dic['name'] = val[val.find('/')+1:-1]
        return dic
        
    if(num == 18):
        dic = {'EntryNo':El,'Element':'Sextupole'}
        v = [ 'Len[m]', 'Feild[kG]','','']
        for i, val in enumerate(c):
            if(isAnumber(val)):            
                dic[v[i]]=float(val)
            else:
                dic['name'] = val[val.find('/')+1:-1]
        return dic
        
    if(num == 19):
        dic = {'EntryNo':El,'Element':'Solenoid'}
        v = [ 'Len[m]', 'Feild[kG]','FeildGrad','']
        for i, val in enumerate(c):
            if(isAnumber(val)):            
                dic[v[i]]=float(val)
            else:
                dic['name'] = val[val.find('/')+1:-1]
        return dic
        
    if(num == 20):
        dic = {'EntryNo':El,'Element':'BeamRot'}
        v = [ 'Rot[deg]', '','','']
        for i, val in enumerate(c):
            if(isAnumber(val)):            
                dic[v[i]]=float(val)
            else:
                dic['name'] = val[val.find('/')+1:-1]
        return dic
        
    if(num == 21):
        dic = {'EntryNo':El,'Element':'StrayFeild'}
        v = [ 'Len[m]', 'Feild[kG]','FeildGrad','']
        for i, val in enumerate(c):
            if(isAnumber(val)):            
                dic[v[i]]=float(val)
            else:
                dic['name'] = val[val.find('/')+1:-1]
        return dic

# %%
# strip the comments from the file 
cmds = []
for a in lines:
    a=a.lstrip()
    if(len(a)>0):        
        #remove white spaces 
        a.join(a.split())
        if ( a[0] == '/' or a[0] == '('or a[0] == ' ' or a[0] == '\n'or len(a)==0):
            #its a commnet line         
            #print("comment: ", a)
            a=''
        else:
            # strip comment
            cmtc = a.find('(')
            cmts = a.find('/*')
            cmds.append(a)
# now process commands
ElType = []
for i, c in enumerate(cmds):   
    #remove the ;
    if(c.find(';')>0):
        c = c[0:c.find(';')]
    #print("command: ", c)
    if(c.find(' ')>0):
        El = c[0:c.find(' ')]
    else:
        El = c
    #print("Element: ", El)
    if(isAnumber(El)):
        ElType.append(LookUpEl(El=i,com=c))
       # print (ElType)
print(len(ElType), " commands loaded into the system")
# Out:
# ['11.0', '/MEV/', '.001']
# ['1.0', '/MM/', '.1']
# ['6.0', '/PM/', '.1']
# 174  commands loaded into the system

# %%
# Sort commands from elements
for c in ElType:
    print(c)
# Out:
# {'EntryNo': 0, 'Element': 'ProgramC', 'command': '0'}
# {'EntryNo': 1, 'Element': 'Units', 'oldUnit': 'Pgain[GeV/c]', 'code': 11, 'newUnit': 'MEV', 'ScaleFctr': 0.001}
# {'EntryNo': 2, 'Element': 'Units', 'oldUnit': 'XY[cm]', 'code': 1, 'newUnit': 'MM', 'ScaleFctr': 0.1}
# {'EntryNo': 3, 'Element': 'Units', 'oldUnit': 'dP[%]', 'code': 6, 'newUnit': 'PM', 'ScaleFctr': 0.1}
# {'EntryNo': 4, 'Element': 'In/OutOpts', 'ControlNum': 48.0, 'name': 'ANGL'}
# {'EntryNo': 5, 'Element': 'Beam', 'x[cm]': 2.6, 'Px[mr]': 0.77, 'y': 2.6, 'Py': 0.77, 'Blen[cm]': 0.0, 'disp[%]': 0.0, 'Pmom': 680.0, 'name': 'BEAM'}
# {'EntryNo': 6, 'Element': 'BeamRotElipse', 'R12': 0.0001, 'R13': 0.0, 'R14': 0.0, 'R15': 0.0, 'R16': 0.0, 'R23': 0.0001, 'R24': 0.0, 'R25': 0.0, 'R26': 0.0, 'R34': 0.0, 'R35': 0.0, 'R36': 0.0, 'R45': 0.0, 'R46': 0.0, 'R56': 0.0, 'name': 'CORR'}
# {'EntryNo': 7, 'Element': 'RMatrix', 'Rji': 1.0, 'Rj2': 0.0, 'Rj3': 0.0, 'Rj4': 0.0, 'Rj5': 0.0, 'Rj6': -3.1, 'j': 1.0, 'name': 'R16'}
# {'EntryNo': 8, 'Element': 'BendingMagPar', 'W/2[cm]': 1836.16, 'name': 'MASS'}
# {'EntryNo': 9, 'Element': 'Drift', 'Len[m]': 0.0, 'name': 'VB67'}
# {'EntryNo': 10, 'Element': 'Drift', 'Len[m]': 1.4}
# {'EntryNo': 11, 'Element': 'BendingMagPar', 'Len[cm]': 30.0, 'name': 'BSG'}
# {'EntryNo': 12, 'Element': 'BendingMagPar', 'k2-fringe': 0.45, 'name': 'BSK'}
# {'EntryNo': 13, 'Element': 'BeamRot', 'Rot[deg]': 180.0}
# {'EntryNo': 14, 'Element': 'Rotation', 'angle[deg]': 16.0}
# {'EntryNo': 15, 'Element': 'BendingMag', 'Len[m]': 1.1, 'angle[deg]': 45.0, 'FeildGrad[n]': -0.15, 'name': 'BS7', 'BendRad': 1.400563499208679}
# {'EntryNo': 16, 'Element': 'Rotation', 'angle[deg]': 16.0}
# {'EntryNo': 17, 'Element': 'BeamRot', 'Rot[deg]': -180.0}
# {'EntryNo': 18, 'Element': 'Drift', 'Len[m]': 1.4, 'name': 'VB78'}
# {'EntryNo': 19, 'Element': 'Drift', 'Len[m]': 1.4}
# {'EntryNo': 20, 'Element': 'BeamRot', 'Rot[deg]': 180.0}
# {'EntryNo': 21, 'Element': 'Rotation', 'angle[deg]': 16.0}
# {'EntryNo': 22, 'Element': 'BendingMag', 'Len[m]': 1.1, 'angle[deg]': 45.0, 'FeildGrad[n]': -0.15, 'name': 'BS8', 'BendRad': 1.400563499208679}
# {'EntryNo': 23, 'Element': 'Rotation', 'angle[deg]': 16.0}
# {'EntryNo': 24, 'Element': 'BeamRot', 'Rot[deg]': -180.0}
# {'EntryNo': 25, 'Element': 'Drift', 'Len[m]': 1.4, 'name': 'VB81'}
# {'EntryNo': 26, 'Element': 'Drift', 'Len[m]': 1.4}
# {'EntryNo': 27, 'Element': 'BeamRot', 'Rot[deg]': 180.0}
# {'EntryNo': 28, 'Element': 'Rotation', 'angle[deg]': 16.0}
# {'EntryNo': 29, 'Element': 'BendingMag', 'Len[m]': 1.1, 'angle[deg]': 45.0, 'FeildGrad[n]': -0.15, 'name': 'BS1', 'BendRad': 1.400563499208679}
# {'EntryNo': 30, 'Element': 'Rotation', 'angle[deg]': 16.0}
# {'EntryNo': 31, 'Element': 'BeamRot', 'Rot[deg]': -180.0}
# {'EntryNo': 32, 'Element': 'Drift', 'Len[m]': 1.4, 'name': 'VB12'}
# {'EntryNo': 33, 'Element': 'Drift', 'Len[m]': 1.4}
# {'EntryNo': 34, 'Element': 'BeamRot', 'Rot[deg]': 180.0}
# {'EntryNo': 35, 'Element': 'Rotation', 'angle[deg]': 17.0}
# {'EntryNo': 36, 'Element': 'BendingMag', 'Len[m]': 1.1, 'angle[deg]': 45.0, 'FeildGrad[n]': -0.15, 'name': 'BS2', 'BendRad': 1.400563499208679}
# {'EntryNo': 37, 'Element': 'Rotation', 'angle[deg]': 15.0}
# {'EntryNo': 38, 'Element': 'BeamRot', 'Rot[deg]': -180.0}
# {'EntryNo': 39, 'Element': 'Drift', 'Len[m]': 0.2}
# {'EntryNo': 40, 'Element': 'BendingMagPar', 'Len[cm]': 25.0, 'name': 'ABEG'}
# {'EntryNo': 41, 'Element': 'BendingMagPar', 'k2-fringe': 0.45, 'name': 'ABEK'}
# {'EntryNo': 42, 'Element': 'Rotation', 'angle[deg]': 0.0}
# {'EntryNo': 43, 'Element': 'BendingMag', 'Len[m]': 0.5, 'angle[deg]': 15.0, 'FeildGrad[n]': 0.0, 'name': 'ABE1', 'BendRad': 1.9098593171027443}
# {'EntryNo': 44, 'Element': 'Rotation', 'angle[deg]': 0.0}
# {'EntryNo': 45, 'Element': 'Drift', 'Len[m]': 0.3}
# {'EntryNo': 46, 'Element': 'Rotation', 'angle[deg]': 0.0}
# {'EntryNo': 47, 'Element': 'BendingMag', 'Len[m]': 0.9, 'angle[deg]': 32.0, 'FeildGrad[n]': 0.0, 'name': 'ABE2', 'BendRad': 1.6114437988054404}
# {'EntryNo': 48, 'Element': 'Rotation', 'angle[deg]': 0.0}
# {'EntryNo': 49, 'Element': 'Drift', 'Len[m]': 0.3}
# {'EntryNo': 50, 'Element': 'QP', 'Len[m]': 0.4, 'Feild[kG]': -4.224, 'HalfApature': 50.0, 'name': 'QB1'}
# {'EntryNo': 51, 'Element': 'Drift', 'Len[m]': 0.6}
# {'EntryNo': 52, 'Element': 'Rotation', 'angle[deg]': 0.0}
# {'EntryNo': 53, 'Element': 'BendingMag', 'Len[m]': 0.8, 'angle[deg]': 0.0, 'FeildGrad[n]': 0.0, 'name': 'ABE3', 'BendRad': 0}
# {'EntryNo': 54, 'Element': 'Rotation', 'angle[deg]': 0.0}
# {'EntryNo': 55, 'Element': 'Drift', 'Len[m]': 0.3}
# {'EntryNo': 56, 'Element': 'QP', 'Len[m]': 0.4, 'Feild[kG]': 2.0, 'HalfApature': 50.0, 'name': 'QB2'}
# {'EntryNo': 57, 'Element': 'Drift', 'Len[m]': 0.8}
# {'EntryNo': 58, 'Element': 'QP', 'Len[m]': 0.4, 'Feild[kG]': -1.811, 'HalfApature': 50.0, 'name': 'QB3'}
# {'EntryNo': 59, 'Element': 'Drift', 'Len[m]': 1.3}
# {'EntryNo': 60, 'Element': 'QP', 'Len[m]': 3.7, 'Feild[kG]': 0.0, 'HalfApature': 70.0, 'name': 'Wall'}
# {'EntryNo': 61, 'Element': 'Drift', 'Len[m]': 0.5}
# {'EntryNo': 62, 'Element': 'QP', 'Len[m]': 0.4, 'Feild[kG]': 0.9, 'HalfApature': 50.0, 'name': 'QR4'}
# {'EntryNo': 63, 'Element': 'Drift', 'Len[m]': 0.6}
# {'EntryNo': 64, 'Element': 'QP', 'Len[m]': 0.4, 'Feild[kG]': -1.318, 'HalfApature': 50.0, 'name': 'QR5'}
# {'EntryNo': 65, 'Element': 'Drift', 'Len[m]': 0.5}
# {'EntryNo': 66, 'Element': 'BendingMagPar', 'Len[cm]': 30.0, 'name': 'ARIG'}
# {'EntryNo': 67, 'Element': 'BendingMagPar', 'k2-fringe': 0.45, 'name': 'ARIK'}
# {'EntryNo': 68, 'Element': 'Rotation', 'angle[deg]': -2.0}
# {'EntryNo': 69, 'Element': 'BendingMag', 'Len[m]': 1.1, 'angle[deg]': 37.0, 'FeildGrad[n]': 0.0, 'name': 'ARI1', 'BendRad': 1.7033880395781231}
# {'EntryNo': 70, 'Element': 'Rotation', 'angle[deg]': -2.0}
# {'EntryNo': 71, 'Element': 'Drift', 'Len[m]': 3.0}
# {'EntryNo': 72, 'Element': 'Drift', 'Len[m]': 0.5, 'name': 'VAIn'}
# {'EntryNo': 73, 'Element': 'QP', 'Len[m]': 1.2, 'Feild[kG]': 0.0, 'HalfApature': 60.0, 'name': 'Valy'}
# {'EntryNo': 74, 'Element': 'QP', 'Len[m]': 1.2, 'Feild[kG]': 0.0, 'HalfApature': 60.0}
# {'EntryNo': 75, 'Element': 'Drift', 'Len[m]': 1.2}
# {'EntryNo': 76, 'Element': 'BendingMagPar', 'Len[cm]': 30.0, 'name': 'ARIG'}
# {'EntryNo': 77, 'Element': 'BendingMagPar', 'k2-fringe': 0.45, 'name': 'ARIK'}
# {'EntryNo': 78, 'Element': 'Rotation', 'angle[deg]': 10.0}
# {'EntryNo': 79, 'Element': 'BendingMag', 'Len[m]': 1.18, 'angle[deg]': 42.0, 'FeildGrad[n]': 0.0, 'name': 'ARI2', 'BendRad': 1.6097385672723128}
# {'EntryNo': 80, 'Element': 'Rotation', 'angle[deg]': 5.0}
# {'EntryNo': 81, 'Element': 'Drift', 'Len[m]': 1.3}
# {'EntryNo': 82, 'Element': 'QP', 'Len[m]': 0.4, 'Feild[kG]': -0.862, 'HalfApature': 50.0, 'name': 'QR7'}
# {'EntryNo': 83, 'Element': 'Drift', 'Len[m]': 1.0}
# {'EntryNo': 84, 'Element': 'QP', 'Len[m]': 0.4, 'Feild[kG]': 1.691, 'HalfApature': 50.0, 'name': 'QR8'}
# {'EntryNo': 85, 'Element': 'Drift', 'Len[m]': 1.0}
# {'EntryNo': 86, 'Element': 'QP', 'Len[m]': 0.4, 'Feild[kG]': -1.247, 'HalfApature': 50.0, 'name': 'QR9'}
# {'EntryNo': 87, 'Element': 'Drift', 'Len[m]': 1.0}
# {'EntryNo': 88, 'Element': 'BeamRot', 'Rot[deg]': 180.0}
# {'EntryNo': 89, 'Element': 'Rotation', 'angle[deg]': 0.0}
# {'EntryNo': 90, 'Element': 'BendingMag', 'Len[m]': 1.24, 'angle[deg]': 44.0, 'FeildGrad[n]': 0.0, 'name': 'ARI3', 'BendRad': 1.6146992408232292}
# {'EntryNo': 91, 'Element': 'Rotation', 'angle[deg]': 0.0}
# {'EntryNo': 92, 'Element': 'BeamRot', 'Rot[deg]': -180.0}
# {'EntryNo': 93, 'Element': 'Drift', 'Len[m]': 0.55}
# {'EntryNo': 94, 'Element': 'QP', 'Len[m]': 0.4, 'Feild[kG]': 3.254, 'HalfApature': 50.0, 'name': 'QR10'}
# {'EntryNo': 95, 'Element': 'Drift', 'Len[m]': 0.55}
# {'EntryNo': 96, 'Element': 'BeamRot', 'Rot[deg]': 180.0}
# {'EntryNo': 97, 'Element': 'Rotation', 'angle[deg]': 0.0}
# {'EntryNo': 98, 'Element': 'BendingMag', 'Len[m]': 1.4, 'angle[deg]': 50.0, 'FeildGrad[n]': 0.0, 'name': 'ARI4', 'BendRad': 1.604281826366305}
# {'EntryNo': 99, 'Element': 'Rotation', 'angle[deg]': 0.0}
# {'EntryNo': 100, 'Element': 'BeamRot', 'Rot[deg]': -180.0}
# {'EntryNo': 101, 'Element': 'Drift', 'Len[m]': 0.15}
# {'EntryNo': 102, 'Element': 'BeamRot', 'Rot[deg]': 180.0}
# {'EntryNo': 103, 'Element': 'BendingMagPar', 'Len[cm]': 40.0, 'name': 'SM1G'}
# {'EntryNo': 104, 'Element': 'BendingMagPar', 'k2-fringe': 0.45, 'name': 'SM1K'}
# {'EntryNo': 105, 'Element': 'Rotation', 'angle[deg]': 15.0}
# {'EntryNo': 106, 'Element': 'BendingMag', 'Len[m]': 0.61, 'angle[deg]': 27.3, 'FeildGrad[n]': 0.0, 'name': 'SM1C', 'BendRad': 1.2802353664095316}
# {'EntryNo': 107, 'Element': 'Rotation', 'angle[deg]': 11.0}
# {'EntryNo': 108, 'Element': 'BeamRot', 'Rot[deg]': -180.0}
# {'EntryNo': 109, 'Element': 'Drift', 'Len[m]': 0.77, 'name': 'VR12'}
# {'EntryNo': 110, 'Element': 'FitConstr', 'function': 2.0, 'J': 1.0, 'desiredVal]': 0.0, 'accurcy': 0.01, 'name': 'Fixw'}
# {'EntryNo': 111, 'Element': 'FitConstr', 'function': 4.0, 'J': 3.0, 'desiredVal]': 0.0, 'accurcy': 0.01, 'name': 'Fiyw'}
# {'EntryNo': 112, 'Element': 'FitConstr', 'function': 1.0, 'J': 1.0, 'desiredVal]': 2.9, 'accurcy': 0.1, 'name': 'Fitx'}
# {'EntryNo': 113, 'Element': 'FitConstr', 'function': 3.0, 'J': 3.0, 'desiredVal]': 3.1, 'accurcy': 0.1, 'name': 'Fity'}
# {'EntryNo': 114, 'Element': 'Drift', 'Len[m]': 0.77}
# {'EntryNo': 115, 'Element': 'BeamRot', 'Rot[deg]': 180.0}
# {'EntryNo': 116, 'Element': 'Rotation', 'angle[deg]': 11.0}
# {'EntryNo': 117, 'Element': 'BendingMag', 'Len[m]': 0.61, 'angle[deg]': 22.5, 'FeildGrad[n]': -0.35, 'name': 'SM2', 'BendRad': 1.5533522445768986}
# {'EntryNo': 118, 'Element': 'Rotation', 'angle[deg]': 11.0}
# {'EntryNo': 119, 'Element': 'BeamRot', 'Rot[deg]': -180.0}
# {'EntryNo': 120, 'Element': 'Drift', 'Len[m]': 0.77, 'name': 'VR23'}
# {'EntryNo': 121, 'Element': 'Drift', 'Len[m]': 0.77}
# {'EntryNo': 122, 'Element': 'BeamRot', 'Rot[deg]': 180.0}
# {'EntryNo': 123, 'Element': 'Rotation', 'angle[deg]': 10.0}
# {'EntryNo': 124, 'Element': 'BendingMag', 'Len[m]': 0.61, 'angle[deg]': 22.5, 'FeildGrad[n]': -0.35, 'name': 'SM3', 'BendRad': 1.5533522445768986}
# {'EntryNo': 125, 'Element': 'Rotation', 'angle[deg]': 10.0}
# {'EntryNo': 126, 'Element': 'BeamRot', 'Rot[deg]': -180.0}
# {'EntryNo': 127, 'Element': 'Drift', 'Len[m]': 0.77, 'name': 'VR34'}
# {'EntryNo': 128, 'Element': 'Drift', 'Len[m]': 0.77}
# {'EntryNo': 129, 'Element': 'BeamRot', 'Rot[deg]': 180.0}
# {'EntryNo': 130, 'Element': 'Rotation', 'angle[deg]': 10.0}
# {'EntryNo': 131, 'Element': 'BendingMag', 'Len[m]': 0.61, 'angle[deg]': 22.5, 'FeildGrad[n]': -0.35, 'name': 'SM4', 'BendRad': 1.5533522445768986}
# {'EntryNo': 132, 'Element': 'Rotation', 'angle[deg]': 10.0}
# {'EntryNo': 133, 'Element': 'BeamRot', 'Rot[deg]': -180.0}
# {'EntryNo': 134, 'Element': 'Drift', 'Len[m]': 0.77, 'name': 'VR45'}
# {'EntryNo': 135, 'Element': 'FitConstr', 'function': -1.0, 'J': 6.0, 'desiredVal]': 0.0, 'accurcy': -4.0, 'name': 'FitD'}
# {'EntryNo': 136, 'Element': 'Drift', 'Len[m]': 0.77}
# {'EntryNo': 137, 'Element': 'BeamRot', 'Rot[deg]': 180.0}
# {'EntryNo': 138, 'Element': 'Rotation', 'angle[deg]': 10.0}
# {'EntryNo': 139, 'Element': 'BendingMag', 'Len[m]': 0.61, 'angle[deg]': 22.5, 'FeildGrad[n]': -0.35, 'name': 'SM5', 'BendRad': 1.5533522445768986}
# {'EntryNo': 140, 'Element': 'Rotation', 'angle[deg]': 10.0}
# {'EntryNo': 141, 'Element': 'BeamRot', 'Rot[deg]': -180.0}
# {'EntryNo': 142, 'Element': 'Drift', 'Len[m]': 0.77, 'name': 'VR56'}
# {'EntryNo': 143, 'Element': 'Drift', 'Len[m]': 0.77}
# {'EntryNo': 144, 'Element': 'BeamRot', 'Rot[deg]': 180.0}
# {'EntryNo': 145, 'Element': 'Rotation', 'angle[deg]': 10.0}
# {'EntryNo': 146, 'Element': 'BendingMag', 'Len[m]': 0.61, 'angle[deg]': 22.5, 'FeildGrad[n]': -0.35, 'name': 'SM6', 'BendRad': 1.5533522445768986}
# {'EntryNo': 147, 'Element': 'Rotation', 'angle[deg]': 10.0}
# {'EntryNo': 148, 'Element': 'BeamRot', 'Rot[deg]': -180.0}
# {'EntryNo': 149, 'Element': 'Drift', 'Len[m]': 0.77, 'name': 'VR67'}
# {'EntryNo': 150, 'Element': 'Drift', 'Len[m]': 0.77}
# {'EntryNo': 151, 'Element': 'BeamRot', 'Rot[deg]': 180.0}
# {'EntryNo': 152, 'Element': 'Rotation', 'angle[deg]': 10.0}
# {'EntryNo': 153, 'Element': 'BendingMag', 'Len[m]': 0.61, 'angle[deg]': 22.5, 'FeildGrad[n]': -0.35, 'name': 'SM7', 'BendRad': 1.5533522445768986}
# {'EntryNo': 154, 'Element': 'Rotation', 'angle[deg]': 10.0}
# {'EntryNo': 155, 'Element': 'BeamRot', 'Rot[deg]': -180.0}
# {'EntryNo': 156, 'Element': 'Drift', 'Len[m]': 0.77, 'name': 'VR78'}
# {'EntryNo': 157, 'Element': 'Drift', 'Len[m]': 0.77}
# {'EntryNo': 158, 'Element': 'BeamRot', 'Rot[deg]': 180.0}
# {'EntryNo': 159, 'Element': 'Rotation', 'angle[deg]': 10.0}
# {'EntryNo': 160, 'Element': 'BendingMag', 'Len[m]': 0.61, 'angle[deg]': 22.5, 'FeildGrad[n]': -0.35, 'name': 'SM8', 'BendRad': 1.5533522445768986}
# {'EntryNo': 161, 'Element': 'Rotation', 'angle[deg]': 10.0}
# {'EntryNo': 162, 'Element': 'BeamRot', 'Rot[deg]': -180.0}
# {'EntryNo': 163, 'Element': 'Drift', 'Len[m]': 0.77, 'name': 'VR89'}
# {'EntryNo': 165, 'Element': 'ProgramC', 'command': '-1'}
# {'EntryNo': 166, 'Element': 'QP', 'name': 'QR7'}
# {'EntryNo': 167, 'Element': 'QP', 'name': 'QR8'}
# {'EntryNo': 168, 'Element': 'QP', 'name': 'QR9'}
# {'EntryNo': 169, 'Element': 'QP', 'name': 'QR10'}
# {'EntryNo': 170, 'Element': 'FitConstr', 'name': 'FitD'}
# {'EntryNo': 171, 'Element': 'FitConstr', 'name': 'Fitx'}
# {'EntryNo': 172, 'Element': 'FitConstr', 'name': 'Fity'}
# {'EntryNo': 173, 'Element': 'FitConstr', 'name': 'Fixw'}
# {'EntryNo': 174, 'Element': 'FitConstr', 'name': 'Fiyw'}

# %% [markdown]
# ## now we have the data in we can rewrite it to human language in a file

# %%
fout = filename[0:filename.find('.')] + "_converted.txt"
with open (os.path.join(inputDir, fout), 'w') as f:
    #parse the lines
    f.write("element # \t type\t name \t properties\n")
    for dic in ElType:
        #print(dic)
        f.write(str(dic['EntryNo']))
        f.write('\t')
        f.write(str(dic['Element']))
        f.write('\t')
        try:
            f.write(str(dic['name']))            
        except:
            f.write(" ")          
        f.write('\t')
        for key in dic:
            if(key!= 'EntryNo' and key!= 'Element'and key!='name'):
                f.write("\t"+key + "\t " + str(dic[key]))
        f.write('\n')
print("file: " ,fout , " written to folder" , inputDir)
# Out:
# file:  Beamline220MeV_converted.txt  written to folder /mnt/c/Users/stu_w/OneDrive/Software/TRANSPORT/scripts

# %% [markdown]
# # elemets sum and properties
# Here the number of elements and there properties are summed up

# %%
#go over elemets 
Magarr =[]
Qparr = []
for ThisEL in ElType:
    #print("This ThisEL:\t", ThisEL)
    for key in ThisEL:
        #print("This Key:\t", key)
        # get sector magnets
        
        if(ThisEL[key]=='BendingMag' ):
            if (len(Magarr)>0):
                Magarr.append(ThisEL)
            else:
                Magarr = [ThisEL]
            
        #get QP's 
        if(ThisEL[key]=='QP'):
            if (len(Qparr)>0):
                Qparr.append(ThisEL)
            else:
                Qparr = [ThisEL]


print ("magnets:\n")
for m in Magarr: 
    
    try:
        name= m['name']
    except:
        name = ''
    try:
        l= m['Len[m]']
    except:
        l = ''
    try:
        Ha= m['BendRad']
    except:
        Ha = ''
    try:
        f= m['angle[deg]']
    except:
        f = ''
   
    
    print('name : ',name,'\tBendRad : ',Ha,'\tangle[deg] : ',f,'\tLen[m] : ',l)
print ("QP:\n")
for q in Qparr: 
    try:
        name= q['name']
    except:
        name = ''
    try:
        l= q['Len[m]']
    except:
        l = ''
    try:
        Ha= q['tHalfApature']
    except:
        Ha = ''
    try:
        f= q['Feild[kG]']
    except:
        f = ''
    print('name : ',name,'\tLen[m] : ',l,'\tHalfApature : ',Ha,'\tFeild[kG] : ',f)
# Out:
# magnets:
#
# name :  BS7 	BendRad :  1.400563499208679 	angle[deg] :  45.0 	Len[m] :  1.1
# name :  BS8 	BendRad :  1.400563499208679 	angle[deg] :  45.0 	Len[m] :  1.1
# name :  BS1 	BendRad :  1.400563499208679 	angle[deg] :  45.0 	Len[m] :  1.1
# name :  BS2 	BendRad :  1.400563499208679 	angle[deg] :  45.0 	Len[m] :  1.1
# name :  ABE1 	BendRad :  1.9098593171027443 	angle[deg] :  15.0 	Len[m] :  0.5
# name :  ABE2 	BendRad :  1.6114437988054404 	angle[deg] :  32.0 	Len[m] :  0.9
# name :  ABE3 	BendRad :  0 	angle[deg] :  0.0 	Len[m] :  0.8
# name :  ARI1 	BendRad :  1.7033880395781231 	angle[deg] :  37.0 	Len[m] :  1.1
# name :  ARI2 	BendRad :  1.6097385672723128 	angle[deg] :  42.0 	Len[m] :  1.18
# name :  ARI3 	BendRad :  1.6146992408232292 	angle[deg] :  44.0 	Len[m] :  1.24
# name :  ARI4 	BendRad :  1.604281826366305 	angle[deg] :  50.0 	Len[m] :  1.4
# name :  SM1C 	BendRad :  1.2802353664095316 	angle[deg] :  27.3 	Len[m] :  0.61
# name :  SM2 	BendRad :  1.5533522445768986 	angle[deg] :  22.5 	Len[m] :  0.61
# name :  SM3 	BendRad :  1.5533522445768986 	angle[deg] :  22.5 	Len[m] :  0.61
# name :  SM4 	BendRad :  1.5533522445768986 	angle[deg] :  22.5 	Len[m] :  0.61
# name :  SM5 	BendRad :  1.5533522445768986 	angle[deg] :  22.5 	Len[m] :  0.61
# name :  SM6 	BendRad :  1.5533522445768986 	angle[deg] :  22.5 	Len[m] :  0.61
# name :  SM7 	BendRad :  1.5533522445768986 	angle[deg] :  22.5 	Len[m] :  0.61
# name :  SM8 	BendRad :  1.5533522445768986 	angle[deg] :  22.5 	Len[m] :  0.61
# name :  QB1 	Len[m] :  0.4 	HalfApature :   	Feild[kG] :  -4.224
# name :  QB2 	Len[m] :  0.4 	HalfApature :   	Feild[kG] :  2.0
# name :  QB3 	Len[m] :  0.4 	HalfApature :   	Feild[kG] :  -1.811
# name :  Wall 	Len[m] :  3.7 	HalfApature :   	Feild[kG] :  0.0
# name :  QR4 	Len[m] :  0.4 	HalfApature :   	Feild[kG] :  0.9
# name :  QR5 	Len[m] :  0.4 	HalfApature :   	Feild[kG] :  -1.318
# name :  Valy 	Len[m] :  1.2 	HalfApature :   	Feild[kG] :  0.0
# name :   	Len[m] :  1.2 	HalfApature :   	Feild[kG] :  0.0
# name :  QR7 	Len[m] :  0.4 	HalfApature :   	Feild[kG] :  -0.862
# name :  QR8 	Len[m] :  0.4 	HalfApature :   	Feild[kG] :  1.691
# name :  QR9 	Len[m] :  0.4 	HalfApature :   	Feild[kG] :  -1.247
# name :  QR10 	Len[m] :  0.4 	HalfApature :   	Feild[kG] :  3.254
# name :  QR7 	Len[m] :   	HalfApature :   	Feild[kG] :
# name :  QR8 	Len[m] :   	HalfApature :   	Feild[kG] :
# name :  QR9 	Len[m] :   	HalfApature :   	Feild[kG] :
# name :  QR10 	Len[m] :   	HalfApature :   	Feild[kG] :

# %% [markdown]
# # COSY & TraceWin formats
# Now we have the beamline in a format we can work with it is possible to write input cards for other software,
